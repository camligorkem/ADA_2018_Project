# %% [markdown]
# # Source data exploration

# %%
#imports
import pandas as pd
import numpy as np
from collections import Counter
import re

"""
import findspark
findspark.init()
from pyspark.sql import *
import pyspark.sql.functions as sf
"""
import gensim
from gensim.parsing.preprocessing import STOPWORDS

import warnings
warnings.filterwarnings('ignore')
# Import stopwords with nltk.
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /home/gorkem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Read the data
data_folder = 'sample_data/'
sources = pd.read_table(data_folder+'now-samples-sources.txt',encoding = "ISO-8859-1", skiprows =[0,1], header=None)
                    # names=['textID', '#words','date','country','website','url','title'])
sources.dropna(axis=1, inplace=True)
sources.rename(columns={0:'textID', 1:'#words',2:'date',3:'country',4:'website',5:'url',6:'title'}, inplace=True)
sources.head()
# Out:
#    textID  #words      date country              website  \
# 0   11241     397  13-01-06      US               Kotaku
# 1   11242     757  13-01-06      US       Michigan Radio
# 2   11243     755  13-01-06      US  New York Daily News
# 3   11244    1677  13-01-06      US       OregonLive.com
# 4   21242     794  13-01-11      US         Ars Technica
#
#                                                  url  \
# 0  http://kotaku.com/5973495/author-of-the-warrio...
# 1  http://michiganradio.org/post/thats-what-they-...
# 2  http://www.nydailynews.com/life-style/eats/bes...
# 3  http://www.oregonlive.com/performance/index.ss...
# 4  http://arstechnica.com/gadgets/2013/01/ask-ars...
#
#                                                title
# 0  Author of The Warriors, Cult Film Adapted to H...
# 1  That's What They Say: Dialect Society chooses ...
# 2                        Best of New York: Croissant
# 3  Reflecting on a quarter-century of growth in P...
# 4  Ask Ars: Does Facebook auto-delete content aft...

# %%
sources.shape
# Out:
# (2960, 7)

# %%
sources.dtypes
# Out:
# textID      int64
# #words      int64
# date       object
# country    object
# website    object
# url        object
# title      object
# dtype: object

# %%
#sources.date.to_datetime()
sources.date =  '20'+sources.date
sources.date =  pd.to_datetime(sources.date, format='%Y-%m-%d')

# %%
sources.head()
# Out:
#    textID  #words       date country              website  \
# 0   11241     397 2013-01-06      US               Kotaku
# 1   11242     757 2013-01-06      US       Michigan Radio
# 2   11243     755 2013-01-06      US  New York Daily News
# 3   11244    1677 2013-01-06      US       OregonLive.com
# 4   21242     794 2013-01-11      US         Ars Technica
#
#                                                  url  \
# 0  http://kotaku.com/5973495/author-of-the-warrio...
# 1  http://michiganradio.org/post/thats-what-they-...
# 2  http://www.nydailynews.com/life-style/eats/bes...
# 3  http://www.oregonlive.com/performance/index.ss...
# 4  http://arstechnica.com/gadgets/2013/01/ask-ars...
#
#                                                title
# 0  Author of The Warriors, Cult Film Adapted to H...
# 1  That's What They Say: Dialect Society chooses ...
# 2                        Best of New York: Croissant
# 3  Reflecting on a quarter-century of growth in P...
# 4  Ask Ars: Does Facebook auto-delete content aft...

# %%
sources.dtypes
# Out:
# textID              int64
# #words              int64
# date       datetime64[ns]
# country            object
# website            object
# url                object
# title              object
# dtype: object

# %%
# how many unique country?
print(sources.country.unique())
print(len(sources.country.unique()))
# Out:
# ['US' 'IE' 'AU' 'GB' 'CA' 'IN' 'NZ' 'ZA' 'LK' 'SG' 'PH' 'GH' 'NG' 'KE'
#  'HK' 'JM' 'PK' 'BD' 'MY' 'TZ']
# 20

# %%
# how many unique website?
print(sources.website.unique())
print(len(sources.website.unique()))
# Out:
# ['Kotaku' 'Michigan Radio' 'New York Daily News' ...
#  'Business Wire (press release)' 'Fox News' 'Firstcoastnews.com']
# 1104

# %%
# There is any NAN value?
sources.isnull().any().any()
# Out:
# False

# %%
# Are there duplicate lines?
sources.duplicated().any()
# Out:
# False

# %%
# How many articles per country?
articles_per_country = sources.groupby(by=['country'])['textID'].count()
print(articles_per_country)
# Out:
# country
# AU    147
# BD     21
# CA    356
# GB    402
# GH     61
# HK      6
# IE    278
# IN    388
# JM     15
# KE     33
# LK     16
# MY     73
# NG    143
# NZ    126
# PH    118
# PK     80
# SG     98
# TZ      6
# US    396
# ZA    197
# Name: textID, dtype: int64

# %%
# How many website per country?   (count distinct websites)
websites_per_country = sources.groupby(by=['country'])['website'].nunique()
print(websites_per_country)
# Out:
# country
# AU     73
# BD      6
# CA    144
# GB    157
# GH     10
# HK      4
# IE     73
# IN    106
# JM      3
# KE     12
# LK     10
# MY     20
# NG     39
# NZ     33
# PH     27
# PK     25
# SG     32
# TZ      2
# US    283
# ZA     61
# Name: website, dtype: int64

# %%
# How many total words per country?
words_per_country = sources.groupby(by=['country'])['#words'].sum()
print(words_per_country)
# Out:
# country
# AU     90901
# BD      8178
# CA    253240
# GB    250460
# GH     24053
# HK      2149
# IE    141039
# IN    195676
# JM      9705
# KE     13199
# LK     16117
# MY     35644
# NG     68897
# NZ     66178
# PH     57194
# PK     38553
# SG     43241
# TZ      2634
# US    302945
# ZA     95084
# Name: #words, dtype: int64

# %%
# How many articles per website?
articles_per_website = sources.groupby(by=['website'])['textID'].count()
articles_per_website.sort_values(ascending=False, inplace=True)
print(articles_per_website.head(25))
# Out:
# website
# Times of India          95
# Telegraph.co.uk         53
# Independent Online      49
# Daily Mail              46
# Irish Independent       41
# Stuff.co.nz             39
# Irish Times             32
# BBC News                31
# Inquirer.net            29
# The Hindu               28
# The Guardian            27
# Irish Examiner          27
# GhanaWeb                26
# Toronto Star            25
# Goal.com                25
# Globe and Mail          23
# The Independent         21
# News24                  20
# ABC Online              19
# The Nation Newspaper    19
# Otago Daily Times       18
# Vanguard                17
# InterAksyon             17
# CBC.ca                  16
# The42                   16
# Name: textID, dtype: int64

# %%
# Is URLs unique?
sources.url.is_unique
# Out:
# True

# %% [markdown]
# ### Try to find MAIN TOPICS

# %%
# Try to find topic from sources
sources.url.head(10)
# Out:
# 0    http://kotaku.com/5973495/author-of-the-warrio...
# 1    http://michiganradio.org/post/thats-what-they-...
# 2    http://www.nydailynews.com/life-style/eats/bes...
# 3    http://www.oregonlive.com/performance/index.ss...
# 4    http://arstechnica.com/gadgets/2013/01/ask-ars...
# 5    http://worldnews.nbcnews.com/_news/2013/01/11/...
# 6    http://www.independent.ie/sport/other-sports/o...
# 7    http://entertainment.ie/celebrity-gossip/showb...
# 8    http://www.independent.ie/irish-news/courts/de...
# 9    http://www.npr.org/2013/01/22/170007521/rape-a...
# Name: url, dtype: object

# %%
def getWordsFromURL(url):
    return re.compile(r'[\:/?=\-&]+',re.UNICODE).split(url)

# %%
sources['words'] = sources.url.apply(lambda x: getWordsFromURL(x))
sources
# Out:
#         textID  #words       date country                        website  \
# 0        11241     397 2013-01-06      US                         Kotaku
# 1        11242     757 2013-01-06      US                 Michigan Radio
# 2        11243     755 2013-01-06      US            New York Daily News
# 3        11244    1677 2013-01-06      US                 OregonLive.com
# 4        21242     794 2013-01-11      US                   Ars Technica
# 5        21243     690 2013-01-11      US                   NBCNews.com
# 6        31240     701 2013-01-16      IE              Irish Independent
# 7        31241     336 2013-01-16      IE               Entertainment.ie
# 8        31242     262 2013-01-16      IE              Irish Independent
# 9        41240     764 2013-01-22      US                            NPR
# 10       41241     278 2013-01-22      US                         Scope
# 11       41244     827 2013-01-22      US                          KQED
# 12       51243     736 2013-01-26      AU              Gizmodo Australia
# 13       61240     367 2013-01-31      GB        Manchester Evening News
# 14       61242     683 2013-01-31      GB                 Liverpool Echo
# 15       71240     898 2013-02-06      CA                 Financial Post
# 16       71241     856 2013-02-06      CA                  National Post
# 17       71242    1005 2013-02-06      CA                 Globe and Mail
# 18       71243     784 2013-02-06      CA                  National Post
# 19       71244     392 2013-02-06      CA                  National Post
# 20       81241     414 2013-02-11      IN                 Times of India
# 21       81242     231 2013-02-11      IN                       Livemint
# 22       81243     231 2013-02-11      IN                 Economic Times
# 23       91241     927 2013-02-16      CA            Winnipeg Free Press
# 24       91242     579 2013-02-16      CA                 Globe and Mail
# 25       91243     922 2013-02-16      CA                 Globe and Mail
# 26       91244     619 2013-02-16      CA                   McGill Daily
# 27      101240     835 2013-02-21      GB                Telegraph.co.uk
# 28      101241     361 2013-02-21      GB                     Daily Mail
# 29      101244     674 2013-02-21      GB                     Daily Mail
# ...        ...     ...        ...     ...                            ...
# 2930  15561243     583 2016-11-24      NZ              Otago Daily Times
# 2931  15571240     454 2016-11-25      IE                         Closer
# 2932  15571242     327 2016-11-25      IE                   Pundit Arena
# 2933  15571243     263 2016-11-25      IE                         Afloat
# 2934  15571244     180 2016-11-25      IE                  thejournal.ie
# 2935  15581241     459 2016-11-25      IN       http://www.newsgram.com/
# 2936  15581242     271 2016-11-25      IN                 Times of India
# 2937  15581243     506 2016-11-25      IN             The Sangai Express
# 2938  15581244     371 2016-11-25      IN             The Indian Express
# 2939  15591241     138 2016-11-26      GB                      Kent Live
# 2940  15591243     149 2016-11-26      GB                   City Of Hype
# 2941  15601240     253 2016-11-27      GB               The Sport Review
# 2942  15601242    1145 2016-11-27      GB              ESPN.co.uk (blog)
# 2943  15601243     238 2016-11-27      GB                Telegraph.co.uk
# 2944  15601244     123 2016-11-27      GB                     Daily Mail
# 2945  15611240    1362 2016-11-27      NZ    Scoop.co.nz (press release)
# 2946  15611241    1060 2016-11-27      NZ                     Gameplanet
# 2947  15611242     121 2016-11-27      NZ                        Newshub
# 2948  15621242     304 2016-11-28      NG                       TODAY.ng
# 2949  15621244     412 2016-11-28      NG                       TODAY.ng
# 2945                 Free Press, ACT's regular bulletin
# 2946  BlizzCon 2016 was really more like OverwatchCo...
# 2947           Farms no longer NZ's riskiest workplaces
# 2948  Naira has lost 85 percent of its value in two ...
# 2949  Schweinsteiger should make Manchester United '...
# 2950                            Trump: Looking for Love
# 2951  Kellyanne Conway tweets photo of her by Trump'...
# 2952  Trump selects Tom Price as secretary of Health...
# 2953  Liechtenstein bank's Chinese parent says no mo...
# 2954  Ohio State University attack: 'First picture' ...
# 2955  Jungle Disk Appoints Matt Bradley to Board of ...
# 2956  Department of Homeland Security overwhelmed by...
# 2957  Flames surround Ripley's Aquarium, thousands o...
# 2958  Alexis Bledel is working on a Sisterhood of th...
# 2959  Jose Mourinho Has Found An Effective Role For ...
#
#                                                   words
# 0     [http, kotaku.com, 5973495, author, of, the, w...
# 1     [http, michiganradio.org, post, thats, what, t...
# 2     [http, www.nydailynews.com, life, style, eats,...
# 3     [http, www.oregonlive.com, performance, index....
# 4     [http, arstechnica.com, gadgets, 2013, 01, ask...
# 5     [http, worldnews.nbcnews.com, _news, 2013, 01,...
# 6     [http, www.independent.ie, sport, other, sport...
# 7     [http, entertainment.ie, celebrity, gossip, sh...
# 8     [http, www.independent.ie, irish, news, courts...
# 9     [http, www.npr.org, 2013, 01, 22, 170007521, r...
# 10    [http, scopeblog.stanford.edu, 2013, 01, 22, h...
# 11    [http, blogs.kqed.org, makingof, 2013, 01, 22,...
# 12    [http, www.gizmodo.com.au, 2013, 01, mpaa, lob...
# 13    [http, www.manchestereveningnews.co.uk, news, ...
# 14    [http, www.liverpoolecho.co.uk, news, liverpoo...
# 15    [http, business.financialpost.com, fp, comment...
# 16    [http, news.nationalpost.com, full, comment, j...
# 17    [http, www.theglobeandmail.com, arts, books, a...
# 18    [http, news.nationalpost.com, news, canada, in...
# 19    [http, news.nationalpost.com, news, mary, leak...
# 20    [http, timesofindia.indiatimes.com, business, ...
# 21    [http, www.livemint.com, Leisure, 1nl1EKmcj16Y...
# 22    [http, articles.economictimes.indiatimes.com, ...
# 23    [http, www.winnipegfreepress.com, arts, and, l...
# 24    [http, www.theglobeandmail.com, technology, sc...
# 25    [http, www.theglobeandmail.com, life, fashion,...
# 26    [http, www.mcgilldaily.com, 2013, 02, too, few...
# 27    [http, www.telegraph.co.uk, news, uknews, law,...
# 28    [http, www.dailymail.co.uk, health, article, 2...
# 29    [http, www.dailymail.co.uk, sciencetech, artic...
# ...                                                 ...
# 2930  [https, www.odt.co.nz, sport, cricket, interna...
# 2931  [http, lifestyle.one, closer, celebrity, news,...
# 2932  [http, www.punditarena.com, rugby, adrumm, edd...
# 2933  [http, www.afloat.ie, marine, environment, mar...
# 2934  [http, www.thejournal.ie, poll, mandatory, ret...
# 2935  [http, www.newsgram.com, to, encourage, malian...
# 2936  [http, timesofindia.indiatimes.com, india, Ind...
# 2937  [http, www.thesangaiexpress.com, demonetisatio...
# 2938  [http, indianexpress.com, article, india, indi...
# 2939  [http, www.kentlive.news, a, kent, bar, has, m...
# 2940  [http, www.cityofhype.com, playboi, carti, red...
# 2941  [http, www.thesportreview.com, tsr, 2016, 11, ...
# 2942  [http, www.espn.co.uk, blog, sweetspot, post, ...
# 2943  [http, www.telegraph.co.uk, news, 2016, 11, 27...
# 2944  [http, www.dailymail.co.uk, tvshowbiz, article...
# 2945  [http, www.scoop.co.nz, stories, PA1611, S0051...
# 2946  [http, www.gameplanet.co.nz, features, g583b53...
# 2947  [http, www.newshub.co.nz, nznews, farms, no, l...
# 2948  [https, www.today.ng, business, 222759, naira,...
# 2949  [https, www.today.ng, sport, football, 222758,...
# 2950  [http, www.huffingtonpost.com, edward, flattau...
# 2951  [http, www.dailymail.co.uk, news, article, 398...
# 2952  [https, www.theguardian.com, us, news, 2016, n...
# 2953  [http, uk.reuters.com, article, liechtenstein,...
# 2954  [http, www.mirror.co.uk, news, world, news, oh...
# 2955  [http, www.businesswire.com, news, home, 20161...
# 2956  [http, www.foxnews.com, politics, 2016, 11, 29...
# 2957  [http, www.firstcoastnews.com, news, fire, sur...
# 2958  [http, www.ew.com, article, 2016, 11, 29, alex...
# 2959  [http, www.malaysiandigest.com, sports, 645650...
#
# [2960 rows x 8 columns]

# %%
unnecessary_words=['http','https','article','articleshow','new','news']
def removeStopAndUnnecessaryWord(strlist):
    res=[]
    for word in strlist:
        if (word not in (stop)) and (word.isdigit()==False) and (word not in unnecessary_words) and ('www' not in word):
            res.append(word)
    return res

# %%
# Exclude stopwords with Python's list comprehension and pandas.DataFrame.apply.
sources['words_without_stopwords'] = sources['words'].apply(lambda x: removeStopAndUnnecessaryWord(x))
display(sources)
# Out:
#         textID  #words       date country                        website  \
# 0        11241     397 2013-01-06      US                         Kotaku
# 1        11242     757 2013-01-06      US                 Michigan Radio
# 2        11243     755 2013-01-06      US            New York Daily News
# 3        11244    1677 2013-01-06      US                 OregonLive.com
# 4        21242     794 2013-01-11      US                   Ars Technica
# 5        21243     690 2013-01-11      US                   NBCNews.com
# 6        31240     701 2013-01-16      IE              Irish Independent
# 7        31241     336 2013-01-16      IE               Entertainment.ie
# 8        31242     262 2013-01-16      IE              Irish Independent
# 9        41240     764 2013-01-22      US                            NPR
# 10       41241     278 2013-01-22      US                         Scope
# 11       41244     827 2013-01-22      US                          KQED
# 12       51243     736 2013-01-26      AU              Gizmodo Australia
# 13       61240     367 2013-01-31      GB        Manchester Evening News
# 14       61242     683 2013-01-31      GB                 Liverpool Echo
# 15       71240     898 2013-02-06      CA                 Financial Post
# 16       71241     856 2013-02-06      CA                  National Post
# 17       71242    1005 2013-02-06      CA                 Globe and Mail
# 18       71243     784 2013-02-06      CA                  National Post
# 19       71244     392 2013-02-06      CA                  National Post
# 20       81241     414 2013-02-11      IN                 Times of India
# 21       81242     231 2013-02-11      IN                       Livemint
# 22       81243     231 2013-02-11      IN                 Economic Times
# 23       91241     927 2013-02-16      CA            Winnipeg Free Press
# 24       91242     579 2013-02-16      CA                 Globe and Mail
# 25       91243     922 2013-02-16      CA                 Globe and Mail
# 26       91244     619 2013-02-16      CA                   McGill Daily
# 27      101240     835 2013-02-21      GB                Telegraph.co.uk
# 18    'Incompatible with life': Mother's account of ...
# 19    Mary Leakey, the 'grande dame of archeology,' ...
# 20             Indian Railway's total earning up by 20%
# 21    News You Can Use | 24 genes enhance the risk o...
# 22    Banks can open A/cs for Bangladeshi nationals ...
# 23    Tell the dogs something they haven't known all...
# 24    Cyborg rats study shows brain's plasticity for...
# 25        Botox makes you look better - and feel better
# 26    Too few women and minorities in leadership rol...
# 27    Private prisons 'are run better' than those in...
# 28    Red wine isn't just good for your heart - now ...
# 29    Giant sunspot that's SIX TIMES the diameter of...
# ...                                                 ...
# 2930                           International adds spark
# 2931  Katie Price's fans rush to her defence after s...
# 2932  Eddie Jones Aims Antagonising Early Dig At Aus...
# 2933     Open Day For All At Marine Institute This Week
# 2934    Poll: Should mandatory retirement be abolished?
# 2935  To Encourage Malians of Burkina Faso to return...
# 2936  India loses $236 billion due to lead exposure ...
# 2937  Demonetisation of Rs 500, Rs 1000 notes Organi...
# 2938  Bengal trafficking case: Bodies of 2 infants e...
# 2939  A Kent bar has marked the death of Fidel Castr...
# 2940                   Listen: Playboi Carti 'Red Lean'
# 2941  Paul Merson accuses Arsene Wenger of papering ...
# 2942  Never forget Castro's legacy in Cuba, on and o...
# 2943  Tony Blair faces threat of new parliamentary i...
# 2944  A touch of Klass! Ola Jordan flaunts slender f...
# 2945                 Free Press, ACT's regular bulletin
# 2946  BlizzCon 2016 was really more like OverwatchCo...
# 2947           Farms no longer NZ's riskiest workplaces
# 2948  Naira has lost 85 percent of its value in two ...
# 2949  Schweinsteiger should make Manchester United '...
# 2950                            Trump: Looking for Love
# 2951  Kellyanne Conway tweets photo of her by Trump'...
# 2952  Trump selects Tom Price as secretary of Health...
# 2953  Liechtenstein bank's Chinese parent says no mo...
# 2954  Ohio State University attack: 'First picture' ...
# 2955  Jungle Disk Appoints Matt Bradley to Board of ...
# 2956  Department of Homeland Security overwhelmed by...
# 2957  Flames surround Ripley's Aquarium, thousands o...
# 2958  Alexis Bledel is working on a Sisterhood of th...
# 2959  Jose Mourinho Has Found An Effective Role For ...
#
#                                                   words  \
# 0     [http, kotaku.com, 5973495, author, of, the, w...
# 1     [http, michiganradio.org, post, thats, what, t...
# 2     [http, www.nydailynews.com, life, style, eats,...
# 3     [http, www.oregonlive.com, performance, index....
# 4     [http, arstechnica.com, gadgets, 2013, 01, ask...
# 5     [http, worldnews.nbcnews.com, _news, 2013, 01,...
# 6     [http, www.independent.ie, sport, other, sport...
# 7     [http, entertainment.ie, celebrity, gossip, sh...
# 8     [http, www.independent.ie, irish, news, courts...
# 9     [http, www.npr.org, 2013, 01, 22, 170007521, r...
# 10    [http, scopeblog.stanford.edu, 2013, 01, 22, h...
# 11    [http, blogs.kqed.org, makingof, 2013, 01, 22,...
# 12    [http, www.gizmodo.com.au, 2013, 01, mpaa, lob...
# 13    [http, www.manchestereveningnews.co.uk, news, ...
# 14    [http, www.liverpoolecho.co.uk, news, liverpoo...
# 15    [http, business.financialpost.com, fp, comment...
# 16    [http, news.nationalpost.com, full, comment, j...
# 17    [http, www.theglobeandmail.com, arts, books, a...
# 18    [http, news.nationalpost.com, news, canada, in...
# 19    [http, news.nationalpost.com, news, mary, leak...
# 20    [http, timesofindia.indiatimes.com, business, ...
# 21    [http, www.livemint.com, Leisure, 1nl1EKmcj16Y...
# 22    [http, articles.economictimes.indiatimes.com, ...
# 23    [http, www.winnipegfreepress.com, arts, and, l...
# 24    [http, www.theglobeandmail.com, technology, sc...
# 25    [http, www.theglobeandmail.com, life, fashion,...
# 26    [http, www.mcgilldaily.com, 2013, 02, too, few...
# 27    [http, www.telegraph.co.uk, news, uknews, law,...
# 28    [http, www.dailymail.co.uk, health, article, 2...
# 29    [http, www.dailymail.co.uk, sciencetech, artic...
# ...                                                 ...
# 2930  [https, www.odt.co.nz, sport, cricket, interna...
# 2931  [http, lifestyle.one, closer, celebrity, news,...
# 2932  [http, www.punditarena.com, rugby, adrumm, edd...
# 2933  [http, www.afloat.ie, marine, environment, mar...
# 2934  [http, www.thejournal.ie, poll, mandatory, ret...
# 2935  [http, www.newsgram.com, to, encourage, malian...
# 2936  [http, timesofindia.indiatimes.com, india, Ind...
# 2937  [http, www.thesangaiexpress.com, demonetisatio...
# 2938  [http, indianexpress.com, article, india, indi...
# 2939  [http, www.kentlive.news, a, kent, bar, has, m...
# 2940  [http, www.cityofhype.com, playboi, carti, red...
# 2941  [http, www.thesportreview.com, tsr, 2016, 11, ...
# 2942  [http, www.espn.co.uk, blog, sweetspot, post, ...
# 2943  [http, www.telegraph.co.uk, news, 2016, 11, 27...
# 2944  [http, www.dailymail.co.uk, tvshowbiz, article...
# 2945  [http, www.scoop.co.nz, stories, PA1611, S0051...
# 2946  [http, www.gameplanet.co.nz, features, g583b53...
# 2947  [http, www.newshub.co.nz, nznews, farms, no, l...
# 2948  [https, www.today.ng, business, 222759, naira,...
# 2949  [https, www.today.ng, sport, football, 222758,...
# 2950  [http, www.huffingtonpost.com, edward, flattau...
# 2951  [http, www.dailymail.co.uk, news, article, 398...
# 2952  [https, www.theguardian.com, us, news, 2016, n...
# 2953  [http, uk.reuters.com, article, liechtenstein,...
# 2954  [http, www.mirror.co.uk, news, world, news, oh...
# 2955  [http, www.businesswire.com, news, home, 20161...
# 2956  [http, www.foxnews.com, politics, 2016, 11, 29...
# 2957  [http, www.firstcoastnews.com, news, fire, sur...
# 2958  [http, www.ew.com, article, 2016, 11, 29, alex...
# 2959  [http, www.malaysiandigest.com, sports, 645650...
#
#                                 words_without_stopwords
# 0     [kotaku.com, author, warriors, cult, film, ada...
# 1     [michiganradio.org, post, thats, say, dialect,...
# 2     [life, style, eats, best, york, croissant, 1.1...
# 3     [performance, index.ssf, reflecting_on_a_quart...
# 4     [arstechnica.com, gadgets, ask, ars, facebook,...
# 5     [worldnews.nbcnews.com, _news, accused, associ...
# 6     [sport, sports, olympic, star, conlon, aims, r...
# 7     [entertainment.ie, celebrity, gossip, showbiz,...
# 8     [irish, courts, declan, ganley, forced, pay, e...
# 9     [rape, significant, disturbing, feature, syria...
# 10    [scopeblog.stanford.edu, loneliness, impact, i...
# 11    [blogs.kqed.org, makingof, making, digital, el...
# 12           [mpaa, lobbies, army, hollywood, drones, ]
# 13    [greater, manchester, mary, patel, scours, pav...
# 14    [liverpool, ippc, investigate, case, autistic,...
# 15    [business.financialpost.com, fp, comment, farm...
# 16    [news.nationalpost.com, full, comment, james, ...
# 17    [arts, books, media, richard, iii, johnny, rot...
# 18    [news.nationalpost.com, canada, incompatible, ...
# 19    [news.nationalpost.com, mary, leakey, grande, ...
# 20    [timesofindia.indiatimes.com, business, india,...
# 21    [Leisure, 1nl1EKmcj16Ye8ld4rZBjP, News, You, C...
# 22    [articles.economictimes.indiatimes.com, 370391...
# 23    [arts, life, entertainment, books, tell, dogs,...
# 24    [technology, science, cyborg, rats, study, sho...
# 25    [life, fashion, beauty, beauty, sarah, hampson...
# 26    [women, minorities, leadership, roles, report,...
# 27    [uknews, law, order, Private, prisons, run, be...
# 28    [health, Red, wine, isnt, good, heart, experts...
# 29    [sciencetech, Giant, sunspot, thats, SIX, TIME...
# ...                                                 ...
# 2930       [sport, cricket, international, adds, spark]
# 2931  [lifestyle.one, closer, celebrity, katie, pric...
# 2932  [rugby, adrumm, eddie, jones, aims, antagonisi...
# 2933  [marine, environment, marine, science, item, o...
# 2934           [poll, mandatory, retirement, Nov2016, ]
# 2935  [encourage, malians, burkina, faso, return, re...
# 2936  [timesofindia.indiatimes.com, india, India, lo...
# 2937  [demonetisation, rs, rs, notes, organised, loo...
# 2938  [indianexpress.com, india, india, india, benga...
# 2939  [kent, bar, marked, death, fidel, castro, unfo...
# 2940                      [playboi, carti, red, lean, ]
# 2941  [tsr, paul, merson, accuses, arsene, wenger, p...
# 2942  [blog, sweetspot, post, _, id, never, forget, ...
# 2943  [tony, blair, faces, threat, parliamentary, in...
# 2944  [tvshowbiz, A, touch, Klass, Ola, Jordan, flau...
# 2945  [stories, PA1611, S00516, free, press, acts, r...
# 2946  [features, g583b5374a2527, BlizzCon, really, l...
# 2947  [nznews, farms, longer, nzs, riskiest, workpla...
# 2948       [business, naira, lost, percent, years, cbn]
# 2949  [sport, football, schweinsteiger, manchester, ...
# 2950  [edward, flattau, trump, looking, love_b_13292...
# 2951  [The, privilege, lifetime, Kellyanne, Conway, ...
# 2952  [us, nov, tom, price, health, human, services,...
# 2953  [uk.reuters.com, liechtenstein, bank, cybercri...
# 2954    [world, ohio, state, university, attack, first]
# 2955  [home, en, Jungle, Disk, Appoints, Matt, Bradl...
# 2956  [politics, department, homeland, security, ove...
# 2957  [fire, surrounds, ripleys, aquarium, thousands...
# 2958  [alexis, bledel, sisterhood, traveling, pants,...
# 2959  [sports, jose, mourinho, found, effective, rol...
#
# [2960 rows x 9 columns]

# %%
Counter(x for xs in sources.words_without_stopwords for x in set(xs)).most_common(50)
# Out:
# [('', 810),
#  ('business', 140),
#  ('world', 138),
#  ('sport', 97),
#  ('timesofindia.indiatimes.com', 95),
#  ('city', 93),
#  ('story', 87),
#  ('life', 69),
#  ('india', 65),
#  ('entertainment', 61),
#  ('politics', 57),
#  ('says', 56),
#  ('local', 55),
#  ('sports', 52),
#  ('us', 52),
#  ('national', 51),
#  ('articles', 48),
#  ('first', 46),
#  ('uk', 42),
#  ('day', 41),
#  ('police', 41),
#  ('en', 41),
#  ('football', 41),
#  ('man', 40),
#  ('home', 40),
#  ('report', 38),
#  ('year', 36),
#  ('News', 35),
#  ('content', 34),
#  ('opinion', 34),
#  ('stories', 34),
#  ('canada', 33),
#  ('health', 32),
#  ('tv', 31),
#  ('video', 27),
#  ('one', 27),
#  ('singapore', 27),
#  ('top', 27),
#  ('features', 27),
#  ('south', 26),
#  ('id', 26),
#  ('two', 26),
#  ('music', 26),
#  ('GhanaHomePage', 26),
#  ('game', 25),
#  ('best', 25),
#  ('africa', 24),
#  ('back', 24),
#  ('nation', 24),
#  ('ireland', 24)]

# %% [markdown]
# We can see some popular topics in here such as:
# - business
# - world
# - sport / sports
# - entertainment
# - politics
# - national / local
#
# It might be a way to use these once and try to categorize the articles by topic accordingly if a given selected word is in URL.

# %%
topics = ['business','world', 'sport','sports','entertainment',
          'politics','national', 'local','tech','international',
          'weather','health','economy','economics']
def urlContainsTopic(url):
    for t in topics:
        if(t in url):
            return t
    return 'NoTopic'

# %%
sources['topic'] = sources.url.apply(lambda x: urlContainsTopic(x))
display(sources)
# Out:
#         textID  #words       date country                        website  \
# 0        11241     397 2013-01-06      US                         Kotaku
# 1        11242     757 2013-01-06      US                 Michigan Radio
# 2        11243     755 2013-01-06      US            New York Daily News
# 3        11244    1677 2013-01-06      US                 OregonLive.com
# 4        21242     794 2013-01-11      US                   Ars Technica
# 5        21243     690 2013-01-11      US                   NBCNews.com
# 6        31240     701 2013-01-16      IE              Irish Independent
# 7        31241     336 2013-01-16      IE               Entertainment.ie
# 8        31242     262 2013-01-16      IE              Irish Independent
# 9        41240     764 2013-01-22      US                            NPR
# 10       41241     278 2013-01-22      US                         Scope
# 11       41244     827 2013-01-22      US                          KQED
# 12       51243     736 2013-01-26      AU              Gizmodo Australia
# 13       61240     367 2013-01-31      GB        Manchester Evening News
# 14       61242     683 2013-01-31      GB                 Liverpool Echo
# 15       71240     898 2013-02-06      CA                 Financial Post
# 16       71241     856 2013-02-06      CA                  National Post
# 17       71242    1005 2013-02-06      CA                 Globe and Mail
# 18       71243     784 2013-02-06      CA                  National Post
# 19       71244     392 2013-02-06      CA                  National Post
# 20       81241     414 2013-02-11      IN                 Times of India
# 21       81242     231 2013-02-11      IN                       Livemint
# 22       81243     231 2013-02-11      IN                 Economic Times
# 23       91241     927 2013-02-16      CA            Winnipeg Free Press
# 24       91242     579 2013-02-16      CA                 Globe and Mail
# 25       91243     922 2013-02-16      CA                 Globe and Mail
# 26       91244     619 2013-02-16      CA                   McGill Daily
# 27      101240     835 2013-02-21      GB                Telegraph.co.uk
# 28      101241     361 2013-02-21      GB                     Daily Mail
# 29      101244     674 2013-02-21      GB                     Daily Mail
# ...        ...     ...        ...     ...                            ...
# 2930  15561243     583 2016-11-24      NZ              Otago Daily Times
# 2931  15571240     454 2016-11-25      IE                         Closer
# 2932  15571242     327 2016-11-25      IE                   Pundit Arena
# 24    Cyborg rats study shows brain's plasticity for...
# 25        Botox makes you look better - and feel better
# 26    Too few women and minorities in leadership rol...
# 27    Private prisons 'are run better' than those in...
# 28    Red wine isn't just good for your heart - now ...
# 29    Giant sunspot that's SIX TIMES the diameter of...
# ...                                                 ...
# 2930                           International adds spark
# 2931  Katie Price's fans rush to her defence after s...
# 2932  Eddie Jones Aims Antagonising Early Dig At Aus...
# 2933     Open Day For All At Marine Institute This Week
# 2934    Poll: Should mandatory retirement be abolished?
# 2935  To Encourage Malians of Burkina Faso to return...
# 2936  India loses $236 billion due to lead exposure ...
# 2937  Demonetisation of Rs 500, Rs 1000 notes Organi...
# 2938  Bengal trafficking case: Bodies of 2 infants e...
# 2939  A Kent bar has marked the death of Fidel Castr...
# 2940                   Listen: Playboi Carti 'Red Lean'
# 2941  Paul Merson accuses Arsene Wenger of papering ...
# 2942  Never forget Castro's legacy in Cuba, on and o...
# 2943  Tony Blair faces threat of new parliamentary i...
# 2944  A touch of Klass! Ola Jordan flaunts slender f...
# 2945                 Free Press, ACT's regular bulletin
# 2946  BlizzCon 2016 was really more like OverwatchCo...
# 2947           Farms no longer NZ's riskiest workplaces
# 2948  Naira has lost 85 percent of its value in two ...
# 2949  Schweinsteiger should make Manchester United '...
# 2950                            Trump: Looking for Love
# 2951  Kellyanne Conway tweets photo of her by Trump'...
# 2952  Trump selects Tom Price as secretary of Health...
# 2953  Liechtenstein bank's Chinese parent says no mo...
# 2954  Ohio State University attack: 'First picture' ...
# 2955  Jungle Disk Appoints Matt Bradley to Board of ...
# 2956  Department of Homeland Security overwhelmed by...
# 2957  Flames surround Ripley's Aquarium, thousands o...
# 2958  Alexis Bledel is working on a Sisterhood of th...
# 2959  Jose Mourinho Has Found An Effective Role For ...
#
#                                                   words  \
# 0     [http, kotaku.com, 5973495, author, of, the, w...
# 1     [http, michiganradio.org, post, thats, what, t...
# 2     [http, www.nydailynews.com, life, style, eats,...
# 3     [http, www.oregonlive.com, performance, index....
# 4     [http, arstechnica.com, gadgets, 2013, 01, ask...
# 5     [http, worldnews.nbcnews.com, _news, 2013, 01,...
# 6     [http, www.independent.ie, sport, other, sport...
# 7     [http, entertainment.ie, celebrity, gossip, sh...
# 8     [http, www.independent.ie, irish, news, courts...
# 9     [http, www.npr.org, 2013, 01, 22, 170007521, r...
# 10    [http, scopeblog.stanford.edu, 2013, 01, 22, h...
# 11    [http, blogs.kqed.org, makingof, 2013, 01, 22,...
# 12    [http, www.gizmodo.com.au, 2013, 01, mpaa, lob...
# 13    [http, www.manchestereveningnews.co.uk, news, ...
# 14    [http, www.liverpoolecho.co.uk, news, liverpoo...
# 15    [http, business.financialpost.com, fp, comment...
# 16    [http, news.nationalpost.com, full, comment, j...
# 17    [http, www.theglobeandmail.com, arts, books, a...
# 18    [http, news.nationalpost.com, news, canada, in...
# 19    [http, news.nationalpost.com, news, mary, leak...
# 20    [http, timesofindia.indiatimes.com, business, ...
# 21    [http, www.livemint.com, Leisure, 1nl1EKmcj16Y...
# 22    [http, articles.economictimes.indiatimes.com, ...
# 23    [http, www.winnipegfreepress.com, arts, and, l...
# 24    [http, www.theglobeandmail.com, technology, sc...
# 25    [http, www.theglobeandmail.com, life, fashion,...
# 26    [http, www.mcgilldaily.com, 2013, 02, too, few...
# 27    [http, www.telegraph.co.uk, news, uknews, law,...
# 28    [http, www.dailymail.co.uk, health, article, 2...
# 29    [http, www.dailymail.co.uk, sciencetech, artic...
# ...                                                 ...
# 2930  [https, www.odt.co.nz, sport, cricket, interna...
# 2931  [http, lifestyle.one, closer, celebrity, news,...
# 2932  [http, www.punditarena.com, rugby, adrumm, edd...
# 2933  [http, www.afloat.ie, marine, environment, mar...
# 2934  [http, www.thejournal.ie, poll, mandatory, ret...
# 2935  [http, www.newsgram.com, to, encourage, malian...
# 2936  [http, timesofindia.indiatimes.com, india, Ind...
# 2937  [http, www.thesangaiexpress.com, demonetisatio...
# 2938  [http, indianexpress.com, article, india, indi...
# 2939  [http, www.kentlive.news, a, kent, bar, has, m...
# 2940  [http, www.cityofhype.com, playboi, carti, red...
# 2941  [http, www.thesportreview.com, tsr, 2016, 11, ...
# 2942  [http, www.espn.co.uk, blog, sweetspot, post, ...
# 2943  [http, www.telegraph.co.uk, news, 2016, 11, 27...
# 2944  [http, www.dailymail.co.uk, tvshowbiz, article...
# 2945  [http, www.scoop.co.nz, stories, PA1611, S0051...
# 2946  [http, www.gameplanet.co.nz, features, g583b53...
# 2947  [http, www.newshub.co.nz, nznews, farms, no, l...
# 2948  [https, www.today.ng, business, 222759, naira,...
# 2949  [https, www.today.ng, sport, football, 222758,...
# 2950  [http, www.huffingtonpost.com, edward, flattau...
# 2951  [http, www.dailymail.co.uk, news, article, 398...
# 2952  [https, www.theguardian.com, us, news, 2016, n...
# 2953  [http, uk.reuters.com, article, liechtenstein,...
# 2954  [http, www.mirror.co.uk, news, world, news, oh...
# 2955  [http, www.businesswire.com, news, home, 20161...
# 2956  [http, www.foxnews.com, politics, 2016, 11, 29...
# 2957  [http, www.firstcoastnews.com, news, fire, sur...
# 2958  [http, www.ew.com, article, 2016, 11, 29, alex...
# 2959  [http, www.malaysiandigest.com, sports, 645650...
#
#                                 words_without_stopwords          topic
# 0     [kotaku.com, author, warriors, cult, film, ada...        NoTopic
# 1     [michiganradio.org, post, thats, say, dialect,...        NoTopic
# 2     [life, style, eats, best, york, croissant, 1.1...        NoTopic
# 3     [performance, index.ssf, reflecting_on_a_quart...        NoTopic
# 4     [arstechnica.com, gadgets, ask, ars, facebook,...           tech
# 5     [worldnews.nbcnews.com, _news, accused, associ...          world
# 6     [sport, sports, olympic, star, conlon, aims, r...          sport
# 7     [entertainment.ie, celebrity, gossip, showbiz,...  entertainment
# 8     [irish, courts, declan, ganley, forced, pay, e...        NoTopic
# 9     [rape, significant, disturbing, feature, syria...        NoTopic
# 10    [scopeblog.stanford.edu, loneliness, impact, i...        NoTopic
# 11    [blogs.kqed.org, makingof, making, digital, el...        NoTopic
# 12           [mpaa, lobbies, army, hollywood, drones, ]        NoTopic
# 13    [greater, manchester, mary, patel, scours, pav...        NoTopic
# 14    [liverpool, ippc, investigate, case, autistic,...        NoTopic
# 15    [business.financialpost.com, fp, comment, farm...       business
# 16    [news.nationalpost.com, full, comment, james, ...       national
# 17    [arts, books, media, richard, iii, johnny, rot...        NoTopic
# 18    [news.nationalpost.com, canada, incompatible, ...       national
# 19    [news.nationalpost.com, mary, leakey, grande, ...       national
# 20    [timesofindia.indiatimes.com, business, india,...       business
# 21    [Leisure, 1nl1EKmcj16Ye8ld4rZBjP, News, You, C...        NoTopic
# 22    [articles.economictimes.indiatimes.com, 370391...       national
# 23    [arts, life, entertainment, books, tell, dogs,...  entertainment
# 24    [technology, science, cyborg, rats, study, sho...           tech
# 25    [life, fashion, beauty, beauty, sarah, hampson...        NoTopic
# 26    [women, minorities, leadership, roles, report,...        NoTopic
# 27    [uknews, law, order, Private, prisons, run, be...        NoTopic
# 28    [health, Red, wine, isnt, good, heart, experts...         health
# 29    [sciencetech, Giant, sunspot, thats, SIX, TIME...           tech
# ...                                                 ...            ...
# 2930       [sport, cricket, international, adds, spark]          sport
# 2931  [lifestyle.one, closer, celebrity, katie, pric...        NoTopic
# 2932  [rugby, adrumm, eddie, jones, aims, antagonisi...        NoTopic
# 2933  [marine, environment, marine, science, item, o...        NoTopic
# 2934           [poll, mandatory, retirement, Nov2016, ]        NoTopic
# 2935  [encourage, malians, burkina, faso, return, re...        NoTopic
# 2936  [timesofindia.indiatimes.com, india, India, lo...        NoTopic
# 2937  [demonetisation, rs, rs, notes, organised, loo...        NoTopic
# 2938  [indianexpress.com, india, india, india, benga...        NoTopic
# 2939  [kent, bar, marked, death, fidel, castro, unfo...        NoTopic
# 2940                      [playboi, carti, red, lean, ]        NoTopic
# 2941  [tsr, paul, merson, accuses, arsene, wenger, p...          sport
# 2942  [blog, sweetspot, post, _, id, never, forget, ...        NoTopic
# 2943  [tony, blair, faces, threat, parliamentary, in...        NoTopic
# 2944  [tvshowbiz, A, touch, Klass, Ola, Jordan, flau...        NoTopic
# 2945  [stories, PA1611, S00516, free, press, acts, r...        NoTopic
# 2946  [features, g583b5374a2527, BlizzCon, really, l...        NoTopic
# 2947  [nznews, farms, longer, nzs, riskiest, workpla...        NoTopic
# 2948       [business, naira, lost, percent, years, cbn]       business
# 2949  [sport, football, schweinsteiger, manchester, ...          sport
# 2950  [edward, flattau, trump, looking, love_b_13292...        NoTopic
# 2951  [The, privilege, lifetime, Kellyanne, Conway, ...        NoTopic
# 2952  [us, nov, tom, price, health, human, services,...         health
# 2953  [uk.reuters.com, liechtenstein, bank, cybercri...        NoTopic
# 2954    [world, ohio, state, university, attack, first]          world
# 2955  [home, en, Jungle, Disk, Appoints, Matt, Bradl...       business
# 2956  [politics, department, homeland, security, ove...       politics
# 2957  [fire, surrounds, ripleys, aquarium, thousands...        NoTopic
# 2958  [alexis, bledel, sisterhood, traveling, pants,...        NoTopic
# 2959  [sports, jose, mourinho, found, effective, rol...          sport
#
# [2960 rows x 10 columns]

# %%
# Assigned Topics
sources.topic.value_counts()
# Out:
# NoTopic          2045
# business          202
# sport             179
# world             160
# national           72
# entertainment      72
# local              62
# politics           58
# tech               56
# health             43
# economy             5
# economics           3
# weather             3
# Name: topic, dtype: int64

# %%
sources.shape
# Out:
# (2960, 10)

# %% [markdown]
# By using this approach we can only assign around 1/3rd of the articles.

# %% [markdown]
# # WordLemPos Data

# %%
import csv

# %%
wordLemPos_big = pd.read_table(data_folder+'16-10-us.txt', quoting=csv.QUOTE_NONE, encoding = "ISO-8859-1",header=None)

# %%
wordLemPos = wordLemPos_big.copy()

# %%
numRows = len(wordLemPos)

# %%
display(wordLemPos.shape)
wordLemPos.head(20)
# Out:
# (17564427, 5)
#            0           1           2         3       4
# 0   14637197  4739839025  @@14637197       NaN      fo
# 1   14637197  4739839026         <p>       NaN     NaN
# 2   14637197  4739839027         NEW       new     np1
# 3   14637197  4739839028        YORK      york     np1
# 4   14637197  4739839029           (       NaN       (
# 5   14637197  4739839030          AP        ap     np1
# 6   14637197  4739839031           )       NaN       )
# 7   14637197  4739839032          --       NaN  jj_nn1
# 8   14637197  4739839033      Donald    donald     np1
# 9   14637197  4739839034       Trump     trump     nn1
# 10  14637197  4739839035          's        's      ge
# 11  14637197  4739839036    five-day  five-day      jj
# 12  14637197  4739839037        feud      feud     nn1
# 13  14637197  4739839038        with      with      iw
# 14  14637197  4739839039           a         a     at1
# 15  14637197  4739839040      former    former      da
# 16  14637197  4739839041      beauty    beauty     nn1
# 17  14637197  4739839042       queen     queen     nn1
# 18  14637197  4739839043          is        be     vbz
# 19  14637197  4739839044        only      only      rr

# %%
wordLemPos.rename(columns={0:'textID',1:'ID(seq)',2:'word',3:'lemma',4:'PoS'},inplace=True)
wordLemPos = wordLemPos[['textID','lemma']]
# Drop NA values we are not interested in null lemma's since 
# they are not words but special characters and numbers
wordLemPos.dropna(inplace=True)
wordLemPos.shape
# Out:
# (14243729, 2)

# %% [markdown]
# In the WordLemPos data for each news article words are already preprocessed and lemmatized and stemmed. What we need to do first is to get rid off the stop words. And t

# %%
wordLemPos = wordLemPos[:numRows]
display(wordLemPos.shape)
display(wordLemPos.head())
# Out:
# (14243729, 2)
#      textID   lemma
# 2  14637197     new
# 3  14637197    york
# 5  14637197      ap
# 8  14637197  donald
# 9  14637197   trump

# %%
display(wordLemPos)
# Out:
#             textID            lemma
# 3         14637197             york
# 8         14637197           donald
# 9         14637197            trump
# 11        14637197         five-day
# 12        14637197             feud
# 16        14637197           beauty
# 17        14637197            queen
# 21        14637197             late
# 22        14637197          example
# 25        14637197       insistence
# 27        14637197           airing
# 31        14637197        grievance
# 33        14637197           matter
# 35        14637197        political
# 36        14637197             cost
# 40        14637197       republican
# 41        14637197          nominee
# 43        14637197            brash
# 45        14637197  confrontational
# 46        14637197            style
# 48        14637197           thrill
# 50        14637197          million
# 52        14637197        supporter
# 56        14637197            cheer
# 58        14637197        celebrity
# 59        14637197      businessman
# 61        14637197         tenacity
# 63        14637197           thirst
# 65        14637197           verbal
# 66        14637197           combat
# ...            ...              ...
# 17564360  15149866             flag
# 17564362  15149866           appear
# 17564365  15149866            upper
# 17564366  15149866            right
# 17564367  15149866           corner
# 17564370  15149866            hover
# 17564373  15149866          comment
# 17564375  15149866          flagged
# 17564376  15149866          comment
# 17564379  15149866    automatically
# 17564380  15149866             hide
# 17564382  15149866          comment
# 17564383  15149866           thread
# 17564386  15149866          comment
# 17564388  15149866           appear
# 17564391  15149866          website
# 17564392  15149866           and/or
# 17564394  15149866           mobile
# 17564397  15149866           e-mail
# 17564398  15149866          address
# 17564401  15149866           verify
# 17564408  15149866        community
# 17564410  15149866          monitor
# 17564412  15149866            forum
# 17564415  15149866        knowledge
# 17564417  15149866             ketv
# 17564418  15149866        newswatch
# 17564422  15149866        regularly
# 17564423  15149866          monitor
# 17564425  15149866          comment
#
# [6254867 rows x 2 columns]

# %% [markdown]
# ADJ    adjective    new, good, high, special, big, local
# ADP    adposition    on, of, at, with, by, into, under
# ADV    adverb    really, already, still, early, now
# CONJ    conjunction    and, or, but, if, while, although
# DET    determiner, article    the, a, some, most, every, no, which
# NOUN    noun    year, home, costs, time, Africa
# NUM    numeral    twenty-four, fourth, 1991, 14:24
# PRT    particle    at, on, out, over per, that, up, with
# PRON    pronoun    he, their, her, its, my, I, us
# VERB    verb    is, say, told, given, playing, would

# %%
unnecessary_words=['new','good','high','big','with','into','under',
                  'really','already','still','early','while','although','most','every','which',
                  'year','like','time','that','given','would']

# %%
# Find stop words, replace with nullin lemma
wordLemPos['lemma'] = wordLemPos.lemma.apply((lambda x: x if x not in (stop) 
                                              and len(x)>3 
                                              and x not in gensim.parsing.preprocessing.STOPWORDS
                                              and x not in unnecessary_words
                                              else None))
# Drop lemma null - which are the stopwords
wordLemPos.dropna(inplace=True)

# %%
wordLemPos.shape
# Out:
# (6135938, 2)

# %%
wordLemPos.head(10)
# Out:
#       textID       lemma
# 3   14637197        york
# 8   14637197      donald
# 9   14637197       trump
# 11  14637197    five-day
# 12  14637197        feud
# 16  14637197      beauty
# 17  14637197       queen
# 21  14637197        late
# 22  14637197     example
# 25  14637197  insistence

# %%
unique_textID = wordLemPos.textID.unique()
docs =[]
for text_id in unique_textID:
    doc = wordLemPos[wordLemPos.textID==text_id]['lemma'].tolist()
    docs.append(doc)

# %%
len(docs)
# Out:
# 26028

# %%
# bag of words on the dataset
dictionary = gensim.corpora.Dictionary(docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 30-day
# 1 airing
# 2 article
# 3 beauty
# 4 brag
# 5 brash
# 6 businessman
# 7 campaign
# 8 celebrity
# 9 cheer
# 10 combat

# %%
# filter out the tokens that are seen less than x documents
docThreshold = 15
dictionary.filter_extremes(no_below=docThreshold, no_above=0.5, keep_n=100000)

# %%
# create doc2bow
# For each doc have a dictionary stating how many words and how many times each word appears
bow_corpus = [dictionary.doc2bow(doc) for doc in docs]
#bow_corpus[10]

# %%
# Check in a document which word appears how many time, print previous results
bow_doc_10 = bow_corpus[10]
for i in range(len(bow_doc_10)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_10[i][0], 
                                               dictionary[bow_doc_10[i][0]],bow_doc_10[i][1]))
# Out:
# Word 11 ("come") appears 3 time.
# Word 15 ("cost") appears 2 time.
# Word 19 ("example") appears 1 time.
# Word 29 ("local") appears 1 time.
# Word 32 ("need") appears 1 time.
# Word 37 ("people") appears 1 time.
# Word 38 ("period") appears 1 time.
# Word 39 ("political") appears 1 time.
# Word 45 ("service") appears 3 time.
# Word 56 ("unfairly") appears 1 time.
# Word 68 ("basically") appears 1 time.
# Word 78 ("change") appears 1 time.
# Word 108 ("gain") appears 1 time.
# Word 115 ("happen") appears 1 time.
# Word 123 ("instead") appears 1 time.
# Word 146 ("opportunity") appears 1 time.
# Word 152 ("play") appears 1 time.
# Word 188 ("work") appears 2 time.
# Word 210 ("heart") appears 1 time.
# Word 223 ("project") appears 1 time.
# Word 230 ("seat") appears 1 time.
# Word 231 ("seek") appears 1 time.
# Word 242 ("want") appears 3 time.
# Word 259 ("answer") appears 1 time.
# Word 275 ("board") appears 11 time.
# Word 280 ("business") appears 1 time.
# Word 286 ("certain") appears 1 time.
# Word 295 ("comment") appears 2 time.
# Word 320 ("director") appears 1 time.
# Word 334 ("exactly") appears 1 time.
# Word 335 ("expect") appears 1 time.
# Word 358 ("general") appears 1 time.
# Word 377 ("inform") appears 1 time.
# Word 385 ("large") appears 2 time.
# Word 395 ("long") appears 1 time.
# Word 418 ("near") appears 1 time.
# Word 446 ("population") appears 1 time.
# Word 454 ("problem") appears 1 time.
# Word 457 ("public") appears 3 time.
# Word 466 ("rate") appears 3 time.
# Word 473 ("recent") appears 1 time.
# Word 491 ("response") appears 1 time.
# Word 510 ("shut") appears 1 time.
# Word 512 ("significant") appears 1 time.
# Word 526 ("standard") appears 1 time.
# Word 547 ("thing") appears 1 time.
# Word 548 ("think") appears 1 time.
# Word 565 ("understand") appears 1 time.
# Word 574 ("water") appears 3 time.
# Word 590 ("boost") appears 1 time.
# Word 595 ("company") appears 1 time.
# Word 611 ("member") appears 4 time.
# Word 674 ("issue") appears 2 time.
# Word 677 ("know") appears 2 time.
# Word 682 ("management") appears 1 time.
# Word 700 ("safety") appears 1 time.
# Word 707 ("small") appears 1 time.
# Word 736 ("career") appears 1 time.
# Word 745 ("contender") appears 1 time.
# Word 751 ("decade") appears 1 time.
# Word 770 ("including") appears 1 time.
# Word 853 ("field") appears 2 time.
# Word 942 ("perspective") appears 2 time.
# Word 947 ("push") appears 2 time.
# Word 972 ("charge") appears 3 time.
# Word 988 ("retired") appears 2 time.
# Word 993 ("woman") appears 1 time.
# Word 994 ("11th") appears 1 time.
# Word 995 ("2000s") appears 1 time.
# Word 996 ("2018") appears 1 time.
# Word 997 ("30-year") appears 1 time.
# Word 998 ("advocate") appears 1 time.
# Word 999 ("agreement") appears 2 time.
# Word 1000 ("analyze") appears 1 time.
# Word 1001 ("apartment") appears 1 time.
# Word 1002 ("appointee") appears 1 time.
# Word 1003 ("asset") appears 2 time.
# Word 1004 ("avoid") appears 1 time.
# Word 1005 ("blaze") appears 1 time.
# Word 1006 ("boundary") appears 1 time.
# Word 1007 ("budget") appears 1 time.
# Word 1008 ("burden") appears 1 time.
# Word 1009 ("candidate") appears 1 time.
# Word 1010 ("card") appears 1 time.
# Word 1011 ("choice") appears 1 time.
# Word 1012 ("choose") appears 1 time.
# Word 1013 ("cite") appears 1 time.
# Word 1014 ("clean") appears 1 time.
# Word 1015 ("comfortable") appears 2 time.
# Word 1016 ("consumption") appears 1 time.
# Word 1017 ("contribution") appears 1 time.
# Word 1018 ("counsel") appears 1 time.
# Word 1019 ("criticism") appears 1 time.
# Word 1020 ("customer") appears 2 time.
# Word 1021 ("decline") appears 2 time.
# Word 1022 ("deserve") appears 1 time.
# Word 1023 ("despite") appears 2 time.
# Word 1024 ("destroy") appears 1 time.
# Word 1025 ("discuss") appears 2 time.
# Word 1026 ("district") appears 3 time.
# Word 1027 ("elect") appears 1 time.
# Word 1028 ("election") appears 1 time.
# Word 1029 ("employee") appears 1 time.
# Word 1030 ("equal") appears 1 time.
# Word 1031 ("executive") appears 2 time.
# Word 1032 ("experience") appears 4 time.
# Word 1033 ("expertise") appears 2 time.
# Word 1034 ("explosion") appears 2 time.
# Word 1035 ("fact") appears 3 time.
# Word 1036 ("fixed") appears 2 time.
# Word 1037 ("forward") appears 1 time.
# Word 1038 ("frankly") appears 1 time.
# Word 1039 ("frost") appears 3 time.
# Word 1040 ("fund") appears 2 time.
# Word 1041 ("gender") appears 1 time.
# Word 1042 ("helping") appears 1 time.
# Word 1043 ("hide") appears 1 time.
# Word 1044 ("historic") appears 1 time.
# Word 1045 ("home") appears 1 time.
# Word 1046 ("howard") appears 1 time.
# Word 1047 ("incident") appears 2 time.
# Word 1048 ("increase") appears 1 time.
# Word 1049 ("increased") appears 2 time.
# Word 1050 ("increasing") appears 1 time.
# Word 1051 ("incumbent") appears 1 time.
# Word 1052 ("infrastructure") appears 1 time.
# Word 1053 ("insight") appears 1 time.
# Word 1054 ("jack") appears 1 time.
# Word 1055 ("january") appears 2 time.
# Word 1056 ("knowledge") appears 1 time.
# Word 1057 ("knowledgeable") appears 1 time.
# Word 1058 ("labor") appears 1 time.
# Word 1059 ("lack") appears 1 time.
# Word 1060 ("lawsuit") appears 1 time.
# Word 1061 ("litigation") appears 2 time.
# Word 1062 ("live") appears 1 time.
# Word 1063 ("market") appears 4 time.
# Word 1064 ("metropolitan") appears 1 time.
# Word 1065 ("mind") appears 1 time.
# Word 1066 ("money") appears 1 time.
# Word 1067 ("monthly") appears 1 time.
# Word 1068 ("natural") appears 1 time.
# Word 1069 ("newcomer") appears 1 time.
# Word 1070 ("northern") appears 1 time.
# Word 1071 ("offset") appears 1 time.
# Word 1072 ("opposition") appears 1 time.
# Word 1073 ("outsource") appears 1 time.
# Word 1074 ("payment") appears 1 time.
# Word 1075 ("pending") appears 1 time.
# Word 1076 ("pension") appears 1 time.
# Word 1077 ("plenty") appears 1 time.
# Word 1078 ("policy-making") appears 1 time.
# Word 1079 ("position") appears 1 time.
# Word 1080 ("president") appears 1 time.
# Word 1081 ("prime") appears 1 time.
# Word 1082 ("provide") appears 1 time.
# Word 1083 ("re-election") appears 1 time.
# Word 1084 ("relative") appears 1 time.
# Word 1085 ("reliance") appears 1 time.
# Word 1086 ("representation") appears 1 time.
# Word 1087 ("revenue") appears 2 time.
# Word 1088 ("role") appears 1 time.
# Word 1089 ("save") appears 1 time.
# Word 1090 ("share") appears 1 time.
# Word 1091 ("shortfall") appears 1 time.
# Word 1092 ("sixth") appears 1 time.
# Word 1093 ("software") appears 1 time.
# Word 1094 ("steer") appears 1 time.
# Word 1095 ("stint") appears 1 time.
# Word 1096 ("street") appears 1 time.
# Word 1097 ("stringent") appears 1 time.
# Word 1098 ("structure") appears 2 time.
# Word 1099 ("subsequent") appears 1 time.
# Word 1100 ("technical") appears 1 time.
# Word 1101 ("term") appears 1 time.
# Word 1102 ("tout") appears 1 time.
# Word 1103 ("transparency") appears 2 time.
# Word 1104 ("transparent") appears 1 time.
# Word 1105 ("two-year") appears 1 time.
# Word 1106 ("unchanged") appears 1 time.
# Word 1107 ("union") appears 1 time.
# Word 1108 ("utility") appears 9 time.
# Word 1109 ("vital") appears 1 time.
# Word 1110 ("volume") appears 1 time.
# Word 1111 ("voter") appears 1 time.
# Word 1112 ("wholesale") appears 1 time.
# Word 1113 ("writer") appears 1 time.
# Word 1114 ("youth") appears 1 time.

# %%
# TF IDF scores
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.13875160249185722),
#  (1, 0.17715031430766318),
#  (2, 0.27721028525058744),
#  (3, 0.12131747497512263),
#  (4, 0.12347796102459174),
#  (5, 0.1891044232255576),
#  (6, 0.13041958050997313),
#  (7, 0.062166725248688805),
#  (8, 0.11560367908079414),
#  (9, 0.12807161883869791),
#  (10, 0.11848732068045718),
#  (11, 0.025903339805993027),
#  (12, 0.2098881712441338),
#  (13, 0.07310700483804931),
#  (14, 0.04553721662579709),
#  (15, 0.0701098956552853),
#  (16, 0.06377944504270776),
#  (17, 0.08063285966758814),
#  (18, 0.26822299077423606),
#  (19, 0.07583102922564613),
#  (20, 0.15614468491195388),
#  (21, 0.20544178170293612),
#  (22, 0.10073535252794036),
#  (23, 0.12570775136353204),
#  (24, 0.16872380372463114),
#  (25, 0.038929328098851024),
#  (26, 0.05031869614151054),
#  (27, 0.17819931852133633),
#  (28, 0.050998930179784505),
#  (29, 0.06073026832316018),
#  (30, 0.06649222693253704),
#  (31, 0.05082413449427594),
#  (32, 0.1494953527134458),
#  (33, 0.04375062855431459),
#  (34, 0.08233282954234428),
#  (35, 0.05537289918246951),
#  (36, 0.21395666957111653),
#  (37, 0.02826045425081141),
#  (38, 0.07388605736031423),
#  (39, 0.07014770790032673),
#  (40, 0.08706930972970299),
#  (41, 0.12184261576733767),
#  (42, 0.06341762854787839),
#  (43, 0.06922917575957259),
#  (44, 0.0710313579747438),
#  (45, 0.15348518392513374),
#  (46, 0.06595285712277416),
#  (47, 0.10405090961109652),
#  (48, 0.21796972211053503),
#  (49, 0.08882224494857036),
#  (50, 0.20544178170293612),
#  (51, 0.09369344977955193),
#  (52, 0.19613156499066747),
#  (53, 0.13565816557001686),
#  (54, 0.08339110012898177),
#  (55, 0.06091282865912503),
#  (56, 0.17112889927354658),
#  (57, 0.10077179528300287),
#  (58, 0.15767660791142038),
#  (59, 0.1309754028548771),
#  (60, 0.036749024503569656),
#  (61, 0.062300930248229684)]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=4, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.006*"work" + 0.005*"know" + 0.004*"world" + 0.004*"look" + 0.004*"come" + 0.004*"people" + 0.004*"thing" + 0.004*"want" + 0.003*"love" + 0.003*"watch"
# Topic: 1
# Words: 0.019*"company" + 0.012*"share" + 0.010*"million" + 0.009*"market" + 0.009*"price" + 0.008*"stock" + 0.008*"business" + 0.007*"percent" + 0.007*"quarter" + 0.006*"rate"
# Topic: 2
# Words: 0.022*"game" + 0.013*"play" + 0.011*"team" + 0.010*"season" + 0.006*"come" + 0.006*"yard" + 0.006*"week" + 0.006*"player" + 0.005*"think" + 0.005*"series"
# Topic: 3
# Words: 0.031*"trump" + 0.020*"clinton" + 0.012*"election" + 0.010*"campaign" + 0.009*"republican" + 0.009*"state" + 0.008*"voter" + 0.007*"vote" + 0.007*"donald" + 0.007*"woman"
# Topic: 4
# Words: 0.010*"study" + 0.007*"patient" + 0.006*"research" + 0.005*"cancer" + 0.005*"medical" + 0.005*"researcher" + 0.005*"university" + 0.005*"health" + 0.004*"disease" + 0.004*"people"
# Topic: 5
# Words: 0.011*"comment" + 0.007*"information" + 0.006*"service" + 0.006*"department" + 0.006*"city" + 0.006*"need" + 0.005*"public" + 0.005*"state" + 0.005*"people" + 0.005*"report"
# Topic: 6
# Words: 0.011*"school" + 0.011*"student" + 0.009*"state" + 0.008*"city" + 0.007*"county" + 0.007*"area" + 0.007*"people" + 0.006*"water" + 0.005*"north" + 0.005*"south"
# Topic: 7
# Words: 0.009*"school" + 0.008*"family" + 0.005*"child" + 0.005*"people" + 0.005*"come" + 0.005*"event" + 0.005*"home" + 0.004*"help" + 0.004*"work" + 0.004*"community"
# Topic: 8
# Words: 0.021*"police" + 0.009*"officer" + 0.008*"county" + 0.008*"charge" + 0.006*"tell" + 0.006*"woman" + 0.006*"report" + 0.006*"arrest" + 0.005*"according" + 0.005*"court"
# Topic: 9
# Words: 0.009*"people" + 0.007*"state" + 0.007*"country" + 0.006*"government" + 0.006*"force" + 0.005*"american" + 0.004*"group" + 0.004*"president" + 0.004*"city" + 0.004*"military"

# %%
# conjunction

# %% [markdown]
# ### Questions to answer from NOW Corpus Data
#
# - What are the main topics of the published news? (tech, politics, sports, etc.)
# - What are the distributions of these topics over country and time?
# - Is there a dominant tone in the articles based on topic/country/time?
# - What are some mostly used words in the articles?

# %% [markdown]
# ## TO DO XXXXXX
# - write the first query results in a file
# - turn this notebook into script, where we can run on cluster with big data
